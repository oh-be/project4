# %%
import matplotlib.pyplot as plt 
from matplotlib.pylab import rcParams
import pandas as pd
import scipy.stats as sts
import numpy as np
# %matplotlib inline
import seaborn as sns
sns.set(style='darkgrid',font='Arial',font_scale=1.2)
rcParams['figure.figsize'] = 12,8
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# %%
df = pd.read_csv('City_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv')

# %%
columns = df.columns.to_list()

# %%
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       City        NY    NY
# 1     12447         1  Los Angeles       City        CA    CA
# 2     39051         2      Houston       City        TX    TX
# 3     17426         3      Chicago       City        IL    IL
# 4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  2000-01-31  \
# 0       New York-Newark-Jersey City       Queens County    254333.0
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    246626.0
# 2  Houston-The Woodlands-Sugar Land       Harris County    110875.0
# 3          Chicago-Naperville-Elgin         Cook County    165282.0
# 4         San Antonio-New Braunfels        Bexar County    116801.0
#
#    2000-02-29  ...  2021-05-31  2021-06-30  2021-07-31  2021-08-31  \
# 0    256156.0  ...    700899.0    704665.0    708478.0    712125.0
# ...

# %%
illinois = df[df['State']=='IL']

# %%
cook = illinois[illinois['CountyName']=='Cook County']

# %%
cook
# Out:
#        RegionID  SizeRank         RegionName RegionType StateName State  \
# 3         17426         3            Chicago       City        IL    IL
# 523       44597       532             Cicero       City        IL    IL
# 568       50764       577  Arlington Heights       City        IL    IL
# 582       33889       592         Schaumburg       City        IL    IL
# 618       18025       629           Evanston       City        IL    IL
# ...         ...       ...                ...        ...       ...   ...
# 18224     31795     21144               Golf       City        IL    IL
# 18315     32054     21258           Hodgkins       City        IL    IL
# 18597     53214     21606             McCook       City        IL    IL
# 19046     31594     22198         Forestview       City        IL    IL
# 25781     11693     30967        Great Lakes       City        IL    IL
#
#                           Metro   CountyName  2000-01-31  2000-02-29  ...  \
# ...

# %%
cook = cook.drop(columns=['CountyName', 'Metro', 'State', "StateName",'RegionType'],axis=1)

# %%
cook = cook.reset_index()

# %%
cook = cook.drop(columns=['index'],axis=1)

# %%
cook
# Out:
#      RegionID  SizeRank         RegionName  2000-01-31  2000-02-29  \
# 0       17426         3            Chicago    165282.0    165621.0
# 1       44597       532             Cicero    128972.0    129220.0
# 2       50764       577  Arlington Heights    261429.0    261759.0
# 3       33889       592         Schaumburg    206420.0    206899.0
# 4       18025       629           Evanston    302592.0    302905.0
# ..        ...       ...                ...         ...         ...
# 115     31795     21144               Golf    511254.0    512519.0
# 116     32054     21258           Hodgkins    146250.0    144877.0
# 117     53214     21606             McCook    164992.0    162667.0
# 118     31594     22198         Forestview    164312.0    163407.0
# 119     11693     30967        Great Lakes         NaN         NaN
#
#      2000-03-31  2000-04-30  2000-05-31  2000-06-30  2000-07-31  ...  \
# 0      166381.0    167702.0    169196.0    170566.0    172001.0  ...
# ...

# %%
id_rank_info = cook[['RegionID', "SizeRank", "RegionName"]]
dataset = cook.drop(columns=['RegionID', "SizeRank", "RegionName"], axis = 1)

# %%
id_rank_info.to_csv('id_size_region.csv')
dataset.to_csv('dataset.csv')

# %%
#inverted sizerank to represent actual weight of digit

# %%
plot = np.invert(cook['SizeRank'])

# %%
cook['SizeRank'] = plot

# %%
cook
# Out:
#      RegionID  SizeRank         RegionName  2000-01-31  2000-02-29  \
# 0       17426        -4            Chicago    165282.0    165621.0
# 1       44597      -533             Cicero    128972.0    129220.0
# 2       50764      -578  Arlington Heights    261429.0    261759.0
# 3       33889      -593         Schaumburg    206420.0    206899.0
# 4       18025      -630           Evanston    302592.0    302905.0
# ..        ...       ...                ...         ...         ...
# 115     31795    -21145               Golf    511254.0    512519.0
# 116     32054    -21259           Hodgkins    146250.0    144877.0
# 117     53214    -21607             McCook    164992.0    162667.0
# 118     31594    -22199         Forestview    164312.0    163407.0
# 119     11693    -30968        Great Lakes         NaN         NaN
#
#      2000-03-31  2000-04-30  2000-05-31  2000-06-30  2000-07-31  ...  \
# 0      166381.0    167702.0    169196.0    170566.0    172001.0  ...
# ...

# %%
cook.to_csv('cookcounty.csv')

# %%
cook = cook.drop(['RegionID','SizeRank'],axis=1)

# %%
cook = cook.set_index('RegionName')

# %%
cook.transpose()
# Out:
# RegionName   Chicago    Cicero  Arlington Heights  Schaumburg  Evanston  \
# 2000-01-31  165282.0  128972.0           261429.0    206420.0  302592.0
# 2000-02-29  165621.0  129220.0           261759.0    206899.0  302905.0
# 2000-03-31  166381.0  129706.0           262735.0    207706.0  303645.0
# 2000-04-30  167702.0  130518.0           264406.0    208993.0  304993.0
# 2000-05-31  169196.0  131517.0           266390.0    210318.0  306863.0
# ...              ...       ...                ...         ...       ...
# 2021-10-31  291647.0  238760.0           411208.0    335233.0  538210.0
# 2021-11-30  294440.0  240861.0           414526.0    338328.0  544713.0
# 2021-12-31  297088.0  243257.0           417568.0    341091.0  550440.0
# 2022-01-31  299729.0  245957.0           420270.0    343829.0  554475.0
# 2022-02-28  301283.0  247645.0           421782.0    345585.0  556319.0
#
# RegionName  Orland Park  Palatine  Des Plaines    Skokie  Oak Lawn  ...  \
# ...

# %%
cook.to_csv('transposed.csv')

# %%
cook.reset_index()
# Out:
#             RegionName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  \
# 0              Chicago    165282.0    165621.0    166381.0    167702.0
# 1               Cicero    128972.0    129220.0    129706.0    130518.0
# 2    Arlington Heights    261429.0    261759.0    262735.0    264406.0
# 3           Schaumburg    206420.0    206899.0    207706.0    208993.0
# 4             Evanston    302592.0    302905.0    303645.0    304993.0
# ..                 ...         ...         ...         ...         ...
# 115               Golf    511254.0    512519.0    515788.0    520828.0
# 116           Hodgkins    146250.0    144877.0    145472.0    146342.0
# 117             McCook    164992.0    162667.0    162618.0    162454.0
# 118         Forestview    164312.0    163407.0    165091.0    166567.0
# 119        Great Lakes         NaN         NaN         NaN         NaN
#
#      2000-05-31  2000-06-30  2000-07-31  2000-08-31  2000-09-30  ...  \
# ...

# %%
cook.to_csv('cookcounty.csv')

# %%
cook
# Out:
#                    2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# RegionName
# Chicago              165282.0    165621.0    166381.0    167702.0    169196.0
# Cicero               128972.0    129220.0    129706.0    130518.0    131517.0
# Arlington Heights    261429.0    261759.0    262735.0    264406.0    266390.0
# Schaumburg           206420.0    206899.0    207706.0    208993.0    210318.0
# Evanston             302592.0    302905.0    303645.0    304993.0    306863.0
# ...                       ...         ...         ...         ...         ...
# Golf                 511254.0    512519.0    515788.0    520828.0    524009.0
# Hodgkins             146250.0    144877.0    145472.0    146342.0    148481.0
# McCook               164992.0    162667.0    162618.0    162454.0    162897.0
# Forestview           164312.0    163407.0    165091.0    166567.0    168339.0
# Great Lakes               NaN         NaN         NaN         NaN         NaN
#
# ...
